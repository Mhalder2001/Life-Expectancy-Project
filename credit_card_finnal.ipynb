# %% [markdown]
# #  ***Credit Card Fraud Detection*** 💳
#
# This project to detect fraudulent credit card transaction using machine learning techniques We will preprocess the data ,explore it,build models, and evaluate their performances
#
# ## **Goals:**
#
#
# 1.   Preprocess the data
# 2.   Exploring using visualization techniques
# 3.   Using multiple machine learning models
# 5.  Select the best model for fraud detection

# %% [markdown]
# # Import necessary libraries

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data=pd.read_csv(r"F:\archive _credit card dtection\creditcard.csv")
data
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
data.shape
# Out:
# (284807, 31)

# %%
data.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %% [markdown]
# # Missing value cheaking

# %%
data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
data=data.drop('Time',axis=1) # Drop the time

# %%
data['Class'].unique()
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# 0 means not fraud 1 means credit card fraud

# %% [markdown]
# # Cheaking the duplicates  value

# %%
data.duplicated().any()
# Out:
# True

# %%
data[data.duplicated()] ##see the duplicated rows
# Out:
#               V1        V2        V3        V4        V5        V6        V7  \
# 33     -0.529912  0.873892  1.347247  0.145457  0.414209  0.100223  0.711206
# 35     -0.535388  0.865268  1.351076  0.147575  0.433680  0.086983  0.693039
# 113     1.038370  0.127486  0.184456  1.109950  0.441699  0.945283 -0.036715
# 114     1.038370  0.127486  0.184456  1.109950  0.441699  0.945283 -0.036715
# 115     1.038370  0.127486  0.184456  1.109950  0.441699  0.945283 -0.036715
# ...          ...       ...       ...       ...       ...       ...       ...
# 284708  2.018105  0.073226 -1.615154  0.351058  0.333905 -0.676284  0.050474
# 284751  2.050734 -0.364010 -2.542843 -0.729357  2.388455  3.318015 -0.479138
# 284775  1.955547 -0.724606 -1.706511 -0.611145  1.710907  3.914215 -1.248690
# 284785  0.032887  0.545338 -1.185844 -1.729828  2.932315  3.401529  0.337434
# 284793  1.971002 -0.699067 -1.697541 -0.617643  1.718797  3.911336 -1.259306
#
# ...

# %% [markdown]
#  # Remove the duplicate value

# %%
data.drop_duplicates(keep='first',inplace=True)

# %%
data.duplicated().sum() # that is no duplicate value   we remove all duplicated value
# Out:
# 0

# %%
data.shape
# Out:
# (275663, 30)

# %% [markdown]
# # Few characteristics of dataset

# %%
data.describe()
# Out:
#                   V1             V2             V3             V4  \
# count  275663.000000  275663.000000  275663.000000  275663.000000
# mean       -0.037460      -0.002430       0.025520      -0.004359
# std         1.952522       1.667260       1.507538       1.424323
# min       -56.407510     -72.715728     -48.325589      -5.683171
# 25%        -0.941105      -0.614040      -0.843168      -0.862847
# 50%        -0.059659       0.070249       0.200736      -0.035098
# 75%         1.294471       0.819067       1.048461       0.753943
# max         2.454930      22.057729       9.382558      16.875344
#
#                   V5             V6             V7             V8  \
# count  275663.000000  275663.000000  275663.000000  275663.000000
# mean       -0.010660      -0.014206       0.008586      -0.005698
# std         1.378117       1.313213       1.240348       1.191596
# min      -113.743307     -26.160506     -43.557242     -73.216718
# ...

# %%
Not_fraud = len(data[data['Class']==0])
Fraud = len(data[data['Class']==1])
print(Not_fraud)
print(Fraud)
# Out:
# 275190
# 473

# %%
data['Class'].value_counts()
# Out:
# Class
# 0    275190
# 1       473
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## standarize the Amount column

# %%
sc=StandardScaler()
data['Amount']=sc.fit_transform(pd.DataFrame(data['Amount']))

# %%
data
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10  ...       V21       V22  \
# ...

# %%
sns.countplot(x=data['Class'],hue=data['Class'])
# Out:
# <Axes: xlabel='Class', ylabel='count'>

# %%
from  sklearn.model_selection import train_test_split

# %%
x=data.drop('Class',axis=1)
y=data['Class'].ravel()
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=22)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_26736\2539915378.py:2: FutureWarning: Series.ravel is deprecated. The underlying array is already 1D, so ravel is not necessary.  Use `to_numpy()` for conversion to a numpy array instead.
#   y=data['Class'].ravel()

# %%
len(x_train),len(x_test),len(y_test),len(y_train)
# Out:
# (220530, 55133, 55133, 220530)

# %% [markdown]
# ## Building the supervised mode

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, recall_score, confusion_matrix,roc_auc_score,precision_score,f1_score,classification_report

# %%
classifier = {
    "Logistic Regression":LogisticRegression(),
    "Decision Tree classifier":DecisionTreeClassifier(),
    "Random forest Regressor" :RandomForestClassifier(n_jobs=4, random_state=2024,verbose=False),
    "KNearest":KNeighborsClassifier(n_neighbors=5)
  

}
for name,clf in classifier.items():
    print(f"\n============={name}==========")
    clf.fit(x_train,y_train)
    y_predict=clf.predict(x_test)
    print(f"\n Accuracy:{accuracy_score(y_test,y_predict)}")
    print(f"\n Precision:{precision_score(y_test,y_predict)}")
    print(f"\n Recall:{recall_score(y_test,y_predict)}")
    print(f"\n F1 Score:{f1_score(y_test,y_predict)}")
    print(f"\n Confusion matrix:{confusion_matrix(y_test,y_predict)}")
    print(f"\n ROC AUC:{roc_auc_score(y_test,y_predict)}")
    print(f"\n Classification report:{classification_report(y_test,y_predict)}")
# Out:
# =============Logistic Regression==========
#
#  Accuracy:0.9993107576224766
#
#  Precision:0.8823529411764706
#
#  Recall:0.5844155844155844
#
#  F1 Score:0.703125
#
#  Confusion matrix:[[55050     6]
#  [   32    45]]
#
#  ROC AUC:0.7921533022339472
#
#  Classification report:              precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     55056
#            1       0.88      0.58      0.70        77
#
#     accuracy                           1.00     55133
#    macro avg       0.94      0.79      0.85     55133
# weighted avg       1.00      1.00      1.00     55133
#
#
# =============Decision Tree classifier==========
#
#  Accuracy:0.9992200678359603
#
#  Precision:0.7023809523809523
#
#  Recall:0.7662337662337663
#
#  F1 Score:0.7329192546583851
#
#  Confusion matrix:[[55031    25]
#  [   18    59]]
#
#  ROC AUC:0.8828898415591965
#
#  Classification report:              precision    recall  f1-score   support
#
# ...

# %% [markdown]
# # OVER SAMPLING

# %%
x.shape,y.shape
# Out:
# ((275663, 29), (275663,))

# %%
from imblearn.over_sampling import SMOTE #synthetic minority oversampling technique

# %%
x_res,y_res=SMOTE().fit_resample(x,y)

# %%
y_res=pd.Series(y_res)
y_res.value_counts()
# Out:
# 0    275190
# 1    275190
# Name: count, dtype: int64

# %%
x1_train,x1_test,y1_train,y1_test=train_test_split(x_res,y_res,test_size=0.2,random_state=22)

# %%
classifier = {
    "Logistic Regression":LogisticRegression(),
    "Decision Tree classifier":DecisionTreeClassifier(),
    "Random forest Regressor" :RandomForestClassifier(n_jobs=4, random_state=2024,verbose=False),
    "KNearest":KNeighborsClassifier(n_neighbors=5),
   

}
for name,clf in classifier.items():
    print(f"\n============={name}==========")
    clf.fit(x_train,y_train)
    y_predict=clf.predict(x_test)
    print(f"\n Accuracy:{accuracy_score(y_test,y_predict)}")
    print(f"\n Precision:{precision_score(y_test,y_predict)}")
    print(f"\n Recall:{recall_score(y_test,y_predict)}")
    print(f"\n F1 Score:{f1_score(y_test,y_predict)}")      
    print("confusion matrix:\n",(confusion_matrix(y_test, y_predict)))
    print(f"\n ROC AUC:{roc_auc_score(y_test,y_predict)}")
    print(f"\n Classification report:{classification_report(y_test,y_predict)}")
# Out:
# =============Logistic Regression==========
#  Accuracy:0.9993107576224766
#
#  Precision:0.8823529411764706
#
#  Recall:0.5844155844155844
#
#  F1 Score:0.703125
# confusion matrix:
#  [[55050     6]
#  [   32    45]]
#
#  ROC AUC:0.7921533022339472
#
#  Classification report:              precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     55056
#            1       0.88      0.58      0.70        77
#
#     accuracy                           1.00     55133
#    macro avg       0.94      0.79      0.85     55133
# weighted avg       1.00      1.00      1.00     55133
#
#
# =============Decision Tree classifier==========
#
#  Accuracy:0.9992382057932636
#
#  Precision:0.7058823529411765
#
#  Recall:0.7792207792207793
#
#  F1 Score:0.7407407407407407
# confusion matrix:
#  [[55031    25]
#  [   17    60]]
#
#  ROC AUC:0.8893833480527029
#
#  Classification report:              precision    recall  f1-score   support
#
# ...

# %% [markdown]
# Among of them Random forest regressor is the best classifier to predict the problem becasue recall value is high  0.8181 . and auc of roc is 0.90 .because recall=TP/TP+FN, identity the total fraud case out of total fraud case.

# %% [markdown]
# # Appropriate model fitting

# %%
import statsmodels.api as sm

# %%
x1=sm.add_constant(x)
logit_model=sm.Logit(y,x1)
result=logit_model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.004029
#          Iterations 13
#                            Logit Regression Results
# ...
# Dep. Variable:                      y   No. Observations:               275663
# Model:                          Logit   Df Residuals:                   275633
# Method:                           MLE   Df Model:                           29
# Date:                Sun, 25 Aug 2024   Pseudo R-squ.:                  0.6812
# Time:                        15:44:55   Log-Likelihood:                -1110.7
# converged:                       True   LL-Null:                       -3484.6
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -8.6132      0.146    -59.033      0.000      -8.899      -8.327
# ...

# %% [markdown]
# $$
# G-Statistics = -2*(LL-Null-Log-Likelihood) =-2*(-3484.6+1110.7) =4747.8
#
# $$
#
# #### Here number of independent value is 2 here wald statistics is p>|z| that is 0.000<0.05 i.e we reject our null assumption that coefficient of dependent variable is 0. ie our model is significant.

# %% [markdown]
# #### Here p>|z| is greater than 0.05 of (v2,v3,v11,v12,v15-v19,v24,v25,v26) thease values are insigificant .

# %% [markdown]
# ***

# %% [markdown]
# ## Building the Unsupervised Model

# %%
# K mean clusrtering
# Optimal  

from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, max_iter = 200, random_state = 0)
    kmeans.fit_predict(x1_train)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
wcss
# Out:
# [124596938.7633698,
#  55480548.66257742,
#  37285854.29058206,
#  31738233.6856082,
#  28589207.667671263,
#  23048991.661060847,
#  22014782.60657076,
#  20711278.746211596,
#  19713263.810061157,
#  19420226.747037318]

# %%
kmeans = KMeans(n_clusters = 3, max_iter = 200, random_state = 0,init="k-means++").fit(x1_train)

# %%
kmeans
# Out:
# KMeans(max_iter=200, n_clusters=3, random_state=0)

# %%
x_scaled=sc.fit_transform(x)
type(x_scaled)
# Out:
# numpy.ndarray

# %%
from sklearn.decomposition import PCA

# %%
pca=PCA(n_components=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 pca=PCA(n_components=2)
#
# NameError: name 'PCA' is not defined

# %%
reduced_data = pca.fit_transform(x_scaled)

# %%
# To get the explained variance:
pca.explained_variance_ratio_.cumsum()
# Out:
# array([0.06811485, 0.10360376, 0.1389159 , 0.17415229, 0.20926144,
#        0.24425905, 0.27917111, 0.31402758, 0.34883531, 0.38354001])

# %%
kmeans_labels = kmeans.fit_predict(pca_scaled)

# Add cluster labels to the DataFrame
data['KMeans_Cluster'] = kmeans_labels

#Display cluster counts
kmeans_counts = data['KMeans_Cluster'].value_counts()
kmeans_counts
#kmeans_labels
# Out:
# KMeans_Cluster
# 0    262120
# 1     12763
# 2       780
# Name: count, dtype: int64

# %%
pca_scaled
# Out:
# array([[ 0.30311554,  0.34319898],
#        [-0.47191196,  0.12941945],
#        [ 1.74069543, -0.39475711],
#        ...,
#        [-0.06060271,  0.26071782],
#        [-0.40660818,  0.76974914],
#        [ 0.80601295, -0.05061654]])

# %%
x_array = x.values  # Convert DataFrame to NumPy array

plt.scatter(x_array[:, 0], x_array[:, 1], c=kmeans_labels, cmap='viridis')
plt.xlabel('Feature 1')  # Replace with the actual feature name
plt.ylabel('Feature 2')  # Replace with the actual feature name
plt.title('K-Means Clustering')
plt.colorbar(label='Cluster Label')
plt.show()

# %%
x_array
# Out:
# array([[-1.35980713e+00, -7.27811733e-02,  2.53634674e+00, ...,
#          1.33558377e-01, -2.10530535e-02,  2.33169327e-01],
#        [ 1.19185711e+00,  2.66150712e-01,  1.66480113e-01, ...,
#         -8.98309914e-03,  1.47241692e-02, -3.47092005e-01],
#        [-1.35835406e+00, -1.34016307e+00,  1.77320934e+00, ...,
#         -5.53527940e-02, -5.97518406e-02,  1.13770248e+00],
#        ...,
#        [ 1.91956501e+00, -3.01253846e-01, -3.24963981e+00, ...,
#          4.45477214e-03, -2.65608286e-02, -8.96412718e-02],
#        [-2.40440050e-01,  5.30482513e-01,  7.02510230e-01, ...,
#          1.08820735e-01,  1.04532821e-01, -3.18223086e-01],
#        [-5.33412522e-01, -1.89733337e-01,  7.03337367e-01, ...,
#         -2.41530880e-03,  1.36489143e-02,  4.99268889e-01]])

# %%
# ! pip install kneed

# %%
from kneed import KneeLocator

# %%
kl=KneeLocator(range(1,11),wcss,curve="convex",direction='decreasing')
kl.elbow
# Out:
# 3

# %%
from sklearn.cluster import KMeans, DBSCAN

# %%
# Applying K-Means Clustering
kmeans = KMeans(n_clusters=2, random_state=42)
kmeans_labels = kmeans.fit_predict(pca_scaled)
#kmeans_silhouette = silhouette_score(pca_scaled, kmeans_labels)
#kmeans_silhouett

# %%
# Applying DBSCAN Clustering
dbscan = DBSCAN(eps=0.3, min_samples=5)
dbscan_labels = dbscan.fit_predict(pca_scaled)
#dbscan_silhouette = silhouette_score(pca_scaled, dbscan_labels)
#dbscan_silhouette

# %%
plt.figure(figsize=(15, 5))
# K-Means Plot
plt.subplot(1, 3, 1)
plt.scatter(pca_scaled[:, 0], pca_scaled[:, 1], c=kmeans_labels, cmap='viridis')
plt.title(f'K-Means Clustering')
# Out:
# Text(0.5, 1.0, 'K-Means Clustering')

# %%
plt.figure(figsize=(15, 5))
plt.subplot(1, 3, 2)
plt.scatter(pca_scaled[:, 0],pca_scaled[:, 1], c=dbscan_labels, cmap='viridis')
plt.title(f'DBSCAN Clustering')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[85], line 3
#       1 plt.figure(figsize=(15, 5))
#       2 plt.subplot(1, 3, 2)
# ----> 3 plt.scatter(pca_scaled[:, 0],pca_scaled[:, 1], c=dbscan_labels, cmap='viridis')
#       4 plt.title(f'DBSCAN Clustering')
#
# NameError: name 'dbscan_labels' is not defined

# %%
data
# Out:
#                V1         V2        V3        V4        V5        V6  \
# 0       -1.359807  -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1        1.191857   0.266151  0.166480  0.448154  0.060018 -0.082361
# 2       -1.358354  -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3       -0.966272  -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4       -1.158233   0.877737  1.548718  0.403034 -0.407193  0.095921
# ...           ...        ...       ...       ...       ...       ...
# 284802 -11.881118  10.071785 -9.834783 -2.066656 -5.364473 -2.606837
# 284803  -0.732789  -0.055080  2.035030 -0.738589  0.868229  1.058415
# 284804   1.919565  -0.301254 -3.249640 -0.557828  2.630515  3.031260
# 284805  -0.240440   0.530483  0.702510  0.689799 -0.377961  0.623708
# 284806  -0.533413  -0.189733  0.703337 -0.506271 -0.012546 -0.649617
#
#               V7        V8        V9       V10  ...       V22       V23  \
# ...

# %%
data.columns
# Out:
# Index(['V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11',
#        'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21',
#        'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount', 'Class',
#        'KMeans_Cluster'],
#       dtype='object')

# %%
sns.pairplot(data.iloc[:, :2], hue='DBSCAN_Cluster', palette='viridis',data=data)
plt.suptitle('DBSCAN Clustering', y=1.02)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 sns.pairplot(data.iloc[:, :2], hue='DBSCAN_Cluster', palette='viridis',data=data)
#       2 plt.suptitle('DBSCAN Clustering', y=1.02)
#       3 plt.show()
#
# TypeError: pairplot() got multiple values for argument 'data'

# %%
from sklearn.cluster import DBSCAN

# Apply DBSCAN
dbscan = DBSCAN(eps=0.5, min_samples=5)
dbscan_labels = dbscan.fit_predict(x_scaled)

# Add cluster labels to the DataFrame
#data['DBSCAN_Cluster'] = dbscan_labels

# Display cluster counts
#dbscan_counts = data['DBSCAN_Cluster'].value_counts()
#dbscan_counts

# %%
# Identify potential frauds from K-Means (assuming smaller cluster represents fraud)
kmeans_potential_fraud = data[data['KMeans_Cluster'] == kmeans_counts.idxmin()]

# Identify potential frauds from DBSCAN (typically labeled as -1)
dbscan_potential_fraud = data[data['DBSCAN_Cluster'] == -1]

kmeans_potential_fraud_count = len(kmeans_potential_fraud)
dbscan_potential_fraud_count = len(dbscan_potential_fraud)

kmeans_potential_fraud_count, dbscan_potential_fraud_count
# Out:
# (41317, 199359)

# %% [markdown]
# The output (41317, 199359) represents the number of transactions identified as potential frauds by the K-Means and DBSCAN clustering methods, respectively. Here's how you can interpret these numbers:
#
# K-Means Clustering:
#
# 41317 transactions were identified as potential frauds by K-Means.
# This number corresponds to the transactions that belong to the smaller cluster. In clustering, the assumption here is that fraudulent transactions might cluster together in a smaller group because they deviate from the norm.
# DBSCAN Clustering:
#
# 199359 transactions were identified as potential frauds by DBSCAN.
# In DBSCAN, transactions that do not fit well into any cluster (labeled as -1) are considered outliers. These outliers might represent fraudulent transactions, given that frauds often differ significantly from normal patterns.
# Interpretation:
# K-Means: The smaller cluster detected by K-Means suggests that there are 41,317 transactions that could potentially be fraudulent. K-Means might group transactions based on their similarities, and the smaller group is presumed to be fraud.
#
# DBSCAN: DBSCAN identified a much larger number of outliers (199,359) as potential frauds. This is likely because DBSCAN is sensitive to noise and can classify many transactions as outliers if they do not fit into the main clusters.
#
# Considerations:
# High Number of Potential Frauds: The high number of transactions identified by DBSCAN might suggest that the parameters for DBSCAN (e.g., eps and min_samples) could be too strict, leading to a high number of outliers. You might want to adjust these parameters to reduce the number of false positives.
#
# Comparison: The significant difference in the number of potential frauds between the two methods suggests that they are capturing different aspects of the data. It might be beneficial to combine insights from both methods or further refine the clustering parameters.
#
# Would you like to adjust the parameters or investigate these clusters further?
